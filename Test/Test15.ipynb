# %%
#Funcionesparanumerosesterosycosasraras
import Ejercicio15.Ejer12 as ctm
# Graficos normales

import Ejercicio15.Pie as DiagramaPastel


# GRAFICO con limites superiores e inferiores

import Ejercicio15.plotPie as GraficoPastel


#Funciones 
import Ejercicio15.clases_grouped as ClasesAgrupadas
import Ejercicio15.clases_str_sort as clas_str_sort
import Ejercicio15.fa_agrouped as CalcularFABS
import Ejercicio15.format_str as FormatearStrings
import Ejercicio15.frec_abs as abs
import Ejercicio15.frec_acum as FrecAcumulada
import Ejercicio15.frec_rel as FrecRelativa
import Ejercicio15.ordenar_asc as OrdenarArregloAsendente
import Ejercicio15.sort_clases_fa as OrdenarFrecAbsolutas
import Ejercicio15.tabla_grouped as TablaCompleta
import Ejercicio15.tabla as Tabla4Datos
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Funcionesparanumerosesterosycosasraras
# ----> 2 import Ejercicio15.Ejer12 as ctm
#       3 # Graficos normales
#       5 import Ejercicio15.Pie as DiagramaPastel
#
# ModuleNotFoundError: No module named 'Ejercicio15'

# %%
# Datos de entrada
datos = ["Ramirez", "Rodrigez", "Hernandez", "Hernandez", "Rodrigez", "Rodrigez", "Gonzalez", "Gonzalez", 
         "Ramirez", "Hernandez", "Garcia",    "Martinez", "Lopez", "Gonzalez", "Martinez", "Lopez", "Lopez", 
         "Gonzalez", "Gutierrez", "Martinez", "Gonzalez", "Rodrigez", "Perez", "Rodrigez", "Ramirez", "Sanchez",
         "Martinez", "Lopez",    "Sanchez",   "Garcia",
         "Rodrigez", "Hernandez","Gonzalez",  "Sanchez", "Perez", 
         "Rodrigez", "Lopez"   , "Martinez",  "Flores", "Hernandez",
         "Perez",   "Garcia",   "Martinez",   "Hernandez",
         "Sanchez", "Ramirez",  "Garcia",   "Gonzalez", "Garcia", "Flores",
         "Martinez", "Garcia",  "Ramirez",   "Gonzalez",
         "Hernandez", "Lopez",  "Sanchez",  "Martinez", "Martinez", "Perez",
         "Garcia",   "Gonzalez", "Garcia",  "Gutierrez",
         "Hernandez", "Martinez", "Garcia",  "Hernandez", "Garcia", "Gonzalez", 
         "Lopez",    "Hernandez", "Rodrigez", 
         "Martinez", "Gonzalez", "Garcia",  "Hernandez", "Ramirez", "Flores", "Hernandez", "Gutierrez", "Garcia", "Hernandez",
         "Gonzalez", "Garcia",    "Garcia",  "Flores", "Lopez", "Perez", "Sanchez", "Lopez", "Gutierrez", "Sanchez", "Rodrigez",
         "Hernandez", "Hernandez", "Perez",  "Sanchez", "Lopez", "Martinez"
         ]
# Formatea los datos para evitar espacios y excepciones en cadena
datos_formated = FormatearStrings.format_str(datos)

# Ordena la lista de datos
datos_sorted = clas_str_sort.clases_str_sort(datos_formated)

# Calcula la frecuencia absoluta de los datos
clases, fa_ab = abs.frec_abs(datos_sorted)

# Crea una copia de las clases originales sin ordenar
clases_orden = clases.copy()

# Obtiene las frecuencias absolutas ordenadas ascendente
fa_sorted = OrdenarFrecAbsolutas.sort_clases_fa(clases_orden, OrdenarArregloAsendente.ordenar_asc(clases), fa_ab)

# Calcula la frecuencia relativa
frecuencia_rel = FrecRelativa.frec_rel(fa_sorted)

# Calcula la frecuencia relativa acumulada
frecuencia_rel_acum = FrecAcumulada.frec_acum(frecuencia_rel)

# Imprime las clases, su frecuencia relativa y su frecuencia relativa acumulada ordenadas de forma ascendente
Tabla4Datos.tabla(clases, fa_sorted, frecuencia_rel, frecuencia_rel_acum)

# Llama a las gráficas para ingresar sus parámetros

DiagramaPastel.plot_pie(fa_sorted, clases)  # Gráfico de pie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 20
#       2 datos = ["Ramirez", "Rodrigez", "Hernandez", "Hernandez", "Rodrigez", "Rodrigez", "Gonzalez", "Gonzalez",
#       3          "Ramirez", "Hernandez", "Garcia",    "Martinez", "Lopez", "Gonzalez", "Martinez", "Lopez", "Lopez",
#       4          "Gonzalez", "Gutierrez", "Martinez", "Gonzalez", "Rodrigez", "Perez", "Rodrigez", "Ramirez", "Sanchez",
#    (...)
#      17          "Hernandez", "Hernandez", "Perez",  "Sanchez", "Lopez", "Martinez"
#      18          ]
#      19 # Formatea los datos para evitar espacios y excepciones en cadena
# ---> 20 datos_formated = FormatearStrings.format_str(datos)
#      22 # Ordena la lista de datos
#      23 datos_sorted = clas_str_sort.clases_str_sort(datos_formated)
#
# NameError: name 'FormatearStrings' is not defined

# %% [markdown]
# # Considero que el grafico de pastel representa bien los porcentajes de los datos

# %%
import matplotlib.pyplot as plt

class FormatearStrings:
    @staticmethod
    def format_str(datos):
        return [dato.strip() for dato in datos]

class clas_str_sort:
    @staticmethod
    def clases_str_sort(datos_formated):
        return sorted(datos_formated)

def frec_abs(datos_sorted):
    clases = sorted(set(datos_sorted))
    fa_ab = [datos_sorted.count(clase) for clase in clases]
    return clases, fa_ab

class OrdenarArregloAsendente:
    @staticmethod
    def ordenar_asc(arreglo):
        return sorted(arreglo)

class OrdenarFrecAbsolutas:
    @staticmethod
    def sort_clases_fa(clases_orden, clases_asc, fa_ab):
        fa_sorted = []
        for clase in clases_asc:
            index = clases_orden.index(clase)
            fa_sorted.append(fa_ab[index])
        return fa_sorted

class FrecRelativa:
    @staticmethod
    def frec_rel(fa_sorted):
        total = sum(fa_sorted)
        return [fa / total for fa in fa_sorted]

class FrecAcumulada:
    @staticmethod
    def frec_acum(frecuencia_rel):
        frecuencia_rel_acum = []
        acumulado = 0
        for fr in frecuencia_rel:
            acumulado += fr
            frecuencia_rel_acum.append(acumulado)
        return frecuencia_rel_acum

class Tabla4Datos:
    @staticmethod
    def tabla(clases, fa_sorted, frecuencia_rel, frecuencia_rel_acum):
        print("Clase\tFrecuencia Absoluta\tFrecuencia Relativa\tFrecuencia Relativa Acumulada")
        for i in range(len(clases)):
            print(f"{clases[i]}\t{fa_sorted[i]}\t\t\t{frecuencia_rel[i]:.4f}\t\t\t{frecuencia_rel_acum[i]:.4f}")

class DiagramaPastel:
    @staticmethod
    def plot_pie(fa_sorted, clases):
        # Definir colores pastel bonitos
        colores_pastel = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#FFD700', '#C2B280', '#FF6347', '#CD5C5C', '#90EE90', '#FFB6C1']

        plt.figure(figsize=(8, 8))
        plt.pie(fa_sorted, labels=clases, autopct='%1.1f%%', startangle=140, colors=colores_pastel)
        plt.axis('equal')
        plt.title('Diagrama de Pastel de Frecuencias Absolutas')
        plt.show()

# Datos de entrada
datos = ["Ramirez", "Rodrigez", "Hernandez", "Hernandez", "Rodrigez", "Rodrigez", "Gonzalez", "Gonzalez", 
         "Ramirez", "Hernandez", "Garcia", "Martinez", "Lopez", "Gonzalez", "Martinez", "Lopez", "Lopez", 
         "Gonzalez", "Gutierrez", "Martinez", "Gonzalez", "Rodrigez", "Perez", "Rodrigez", "Ramirez", "Sanchez",
         "Martinez", "Lopez", "Sanchez", "Garcia", "Rodrigez", "Hernandez","Gonzalez", "Sanchez", "Perez", 
         "Rodrigez", "Lopez", "Martinez", "Flores", "Hernandez", "Perez", "Garcia", "Martinez", "Hernandez",
         "Sanchez", "Ramirez", "Garcia", "Gonzalez", "Garcia", "Flores", "Martinez", "Garcia", "Ramirez", "Gonzalez",
         "Hernandez", "Lopez", "Sanchez", "Martinez", "Martinez", "Perez", "Garcia", "Gonzalez", "Garcia", "Gutierrez",
         "Hernandez", "Martinez", "Garcia", "Hernandez", "Garcia", "Gonzalez", "Lopez", "Hernandez", "Rodrigez", 
         "Martinez", "Gonzalez", "Garcia", "Hernandez", "Ramirez", "Flores", "Hernandez", "Gutierrez", "Garcia", "Hernandez",
         "Gonzalez", "Garcia", "Garcia", "Flores", "Lopez", "Perez", "Sanchez", "Lopez", "Gutierrez", "Sanchez", "Rodrigez",
         "Hernandez", "Hernandez", "Perez", "Sanchez", "Lopez", "Martinez"]

# Formatea los datos para evitar espacios y excepciones en cadena
datos_formated = FormatearStrings.format_str(datos)

# Ordena la lista de datos
datos_sorted = clas_str_sort.clases_str_sort(datos_formated)

# Calcula la frecuencia absoluta de los datos
clases, fa_ab = frec_abs(datos_sorted)

# Crea una copia de las clases originales sin ordenar
clases_orden = clases.copy()

# Obtiene las frecuencias absolutas ordenadas ascendente
fa_sorted = OrdenarFrecAbsolutas.sort_clases_fa(clases_orden, OrdenarArregloAsendente.ordenar_asc(clases), fa_ab)

# Calcula la frecuencia relativa
frecuencia_rel = FrecRelativa.frec_rel(fa_sorted)

# Calcula la frecuencia relativa acumulada
frecuencia_rel_acum = FrecAcumulada.frec_acum(frecuencia_rel)

# Imprime las clases, su frecuencia relativa y su frecuencia relativa acumulada ordenadas de forma ascendente
Tabla4Datos.tabla(clases, fa_sorted, frecuencia_rel, frecuencia_rel_acum)

# Llama a las gráficas para ingresar sus parámetros
DiagramaPastel.plot_pie(fa_sorted, clases)  # Gráfico de pie
# Out:
# Clase	Frecuencia Absoluta	Frecuencia Relativa	Frecuencia Relativa Acumulada
# Flores	4			0.0400			0.0400
# Garcia	14			0.1400			0.1800
# Gonzalez	12			0.1200			0.3000
# Gutierrez	4			0.0400			0.3400
# Hernandez	15			0.1500			0.4900
# Lopez	10			0.1000			0.5900
# Martinez	12			0.1200			0.7100
# Perez	6			0.0600			0.7700
# Ramirez	6			0.0600			0.8300
# Rodrigez	9			0.0900			0.9200
# Sanchez	8			0.0800			1.0000

# %% [markdown]
# Considero que el grafico de pastel es mejor para representar los datos.
# El el la grafica concluimos que el apellido mas comun es Hernandez con 15.0%
